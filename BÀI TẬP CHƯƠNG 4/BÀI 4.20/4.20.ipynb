# %%
import pandas as pd 
import numpy as np

# %%
euro = pd.read_csv('D:\\BÀI TẬP\\BÀI TẬP CHƯƠNG 4\\BÀI 4.20\\euro2012.csv')

# %% [markdown]
# # 1

# %%
euro['Goals']
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %% [markdown]
# # 2

# %%
print("Có số đội tham gia:",euro['Team'].nunique())
euro['Team'].unique()
# Out:
# Có số đội tham gia: 16
# array(['Croatia', 'Czech Republic', 'Denmark', 'England', 'France',
#        'Germany', 'Greece', 'Italy', 'Netherlands', 'Poland', 'Portugal',
#        'Republic of Ireland', 'Russia', 'Spain', 'Sweden', 'Ukraine'],
#       dtype=object)

# %% [markdown]
# # 3

# %%
euro
# Out:
#     Unnamed: 0                 Team  Goals  Shots on target  Shots off target  \
# 0            0              Croatia      4               13                12
# 1            1       Czech Republic      4               13                18
# 2            2              Denmark      4               10                10
# 3            3              England      5               11                18
# 4            4               France      3               22                24
# 5            5              Germany     10               32                32
# 6            6               Greece      5                8                18
# 7            7                Italy      6               34                45
# 8            8          Netherlands      2               12                36
# 9            9               Poland      2               15                23
# 10          10             Portugal      6               22                42
# ...

# %% [markdown]
# # 4

# %%
euro12 = euro[['Team','Yellow Cards','Red Cards']]

# %%
euro12
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %% [markdown]
# # 5

# %%
euro12.sort_values('Red Cards')
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 14               Sweden             7          0
# 10             Portugal            12          0
# 13                Spain            11          0
# 12               Russia             6          0
# 15              Ukraine             5          0
# 6                Greece             9          1
# 11  Republic of Ireland             6          1
# 9                Poland             7          1

# %%
euro.sort_values('Yellow Cards')
# Out:
#     Unnamed: 0                 Team  Goals  Shots on target  Shots off target  \
# 2            2              Denmark      4               10                10
# 5            5              Germany     10               32                32
# 3            3              England      5               11                18
# 8            8          Netherlands      2               12                36
# 15          15              Ukraine      2                7                26
# 12          12               Russia      5                9                31
# 11          11  Republic of Ireland      1                7                12
# 4            4               France      3               22                24
# 14          14               Sweden      5               17                19
# 9            9               Poland      2               15                23
# 1            1       Czech Republic      4               13                18
# ...

# %% [markdown]
# # 6a

# %%
euro['Yellow Cards'].mean()
# Out:
# np.float64(7.4375)

# %% [markdown]
# # 6b

# %%
euro['Team'][euro['Goals']>6]
# Out:
# 5     Germany
# 13      Spain
# Name: Team, dtype: object

# %% [markdown]
# # 7

# %%
euro[euro['Team'].str.startswith('G')]
# Out:
#    Unnamed: 0     Team  Goals  Shots on target  Shots off target  \
# 5           5  Germany     10               32                32
# 6           6   Greece      5                8                18
#
#   Shooting Accuracy % Goals-to-shots  Total shots (inc. Blocked)  \
# 5            47.80%           15.60%                          80
# 6            30.70%           19.20%                          32
#
#    Hit Woodwork  Penalty goals  ...  Saves made  Saves-to-shots ratio  \
# 5             2              1  ...          10                62.60%
# 6             1              1  ...          13                65.10%
#
#    Fouls Won  Fouls Conceded Offsides  Yellow Cards  Red Cards  Subs on  \
# 5         63              49       12             4          0       15
# 6         67              48       12             9          1       12
#
#    Subs off  Players Used
# 5        15            17
# 6        12            20
#
# [2 rows x 36 columns]

# %% [markdown]
# # 8

# %%
euro.iloc[:,:7]
# Out:
#     Unnamed: 0                 Team  Goals  Shots on target  Shots off target  \
# 0            0              Croatia      4               13                12
# 1            1       Czech Republic      4               13                18
# 2            2              Denmark      4               10                10
# 3            3              England      5               11                18
# 4            4               France      3               22                24
# 5            5              Germany     10               32                32
# 6            6               Greece      5                8                18
# 7            7                Italy      6               34                45
# 8            8          Netherlands      2               12                36
# 9            9               Poland      2               15                23
# 10          10             Portugal      6               22                42
# ...

# %% [markdown]
# # 9

# %%
euro.iloc[:,:-3]
# Out:
#     Unnamed: 0                 Team  Goals  Shots on target  Shots off target  \
# 0            0              Croatia      4               13                12
# 1            1       Czech Republic      4               13                18
# 2            2              Denmark      4               10                10
# 3            3              England      5               11                18
# 4            4               France      3               22                24
# 5            5              Germany     10               32                32
# 6            6               Greece      5                8                18
# 7            7                Italy      6               34                45
# 8            8          Netherlands      2               12                36
# 9            9               Poland      2               15                23
# 10          10             Portugal      6               22                42
# ...

# %%
euro[['Team','Goals','Shooting Accuracy','Yellow Cards','Red Cards']]
# Out:
#                    Team  Goals Shooting Accuracy  Yellow Cards  Red Cards
# 0               Croatia      4            51.90%             9          0
# 1        Czech Republic      4            41.90%             7          0
# 2               Denmark      4            50.00%             4          0
# 3               England      5            50.00%             5          0
# 4                France      3            37.90%             6          0
# 5               Germany     10            47.80%             4          0
# 6                Greece      5            30.70%             9          1
# 7                 Italy      6            43.00%            16          0
# 8           Netherlands      2            25.00%             5          0
# 9                Poland      2            39.40%             7          1
# 10             Portugal      6            34.30%            12          0
# 11  Republic of Ireland      1            36.80%             6          1
# ...

# %%
team_short = euro[['Team','Shooting Accuracy']]
team_short = team_short[team_short['Team'].isin(['England','Italy','Russia'])]

# %%
team_short
# Out:
#        Team Shooting Accuracy
# 3   England            50.00%
# 7     Italy            43.00%
# 12   Russia            22.50%
